# %% [markdown]
# <a href="https://colab.research.google.com/github/Amar-dev4564/ML-DL-Codes/blob/master/Assnt_2_Akart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame(np.random.randn(10000,13))

# %%
data
# Out:
#             0         1         2   ...        10        11        12
# 0    -0.240147  0.639414 -0.149610  ...  0.327731 -2.345318 -0.826778
# 1    -1.630143  0.815094 -1.483133  ...  0.864275  0.385893  1.103267
# 2    -0.424534  0.462870 -0.380006  ...  0.756078  1.198615  0.742349
# 3    -0.976404 -0.087567  2.223855  ... -1.002188 -0.011039 -0.415944
# 4    -0.031906  0.104903  1.193354  ...  0.813791  0.926203  0.245506
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995 -0.383955  0.030433  1.943774  ... -1.908127  0.555448  0.256355
# 9996 -1.563006  3.076659  0.007915  ... -0.789902  0.644167 -0.876413
# 9997 -1.867578 -0.834783 -0.688982  ... -0.373151  0.008547 -0.455108
# 9998  1.348943 -0.368739  0.099996  ... -0.362406  0.527126  0.133259
# 9999 -1.612791 -0.302886 -0.313456  ... -0.084383  0.230086  1.079630
#
# [10000 rows x 13 columns]

# %%
plt.plot(data)
plt.show()
